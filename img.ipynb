# %%
# !pip install Pillow
# !pip install numpy
# Out:
# Collecting Pillow
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 5.6 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.4 MB/s eta 0:00:00
# Installing collected packages: Pillow
# Successfully installed Pillow-10.4.0
# Collecting numpy
#   Downloading numpy-2.1.0-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Downloading numpy-2.1.0-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.6 MB 5.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.6 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.6 MB 7.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 8.9 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.1.0

# %%
from PIL import Image, ImageDraw
import numpy as np

def image_to_led_style(img_path, matrix_size):
    # Load the image
    img = Image.open(img_path)
    img = img.convert('RGB')
    
    # Determine the size of each block
    width, height = img.size
    block_width = width // matrix_size[1]
    block_height = height // matrix_size[0]
    
    # Create a new image with the same dimensions
    new_img = Image.new('RGB', (width, height), 'black')  # Start with a black background
    draw = ImageDraw.Draw(new_img)
    
    # Calculate the center of each block for placing the dot
    dot_radius = min(block_width, block_height) // 4  # Radius of the dot
    
    # Iterate over each block
    for i in range(matrix_size[0]):
        for j in range(matrix_size[1]):
            # Compute the center of the block
            center_x = j * block_width + block_width // 2
            center_y = i * block_height + block_height // 2
            
            # Crop the block and calculate the average color
            block = img.crop((j * block_width, i * block_height, (j + 1) * block_width, (i + 1) * block_height))
            mean_color = tuple(np.array(block).mean(axis=(0, 1)).astype(int))
            
            # Draw the dot
            draw.ellipse([(center_x - dot_radius, center_y - dot_radius),
                          (center_x + dot_radius, center_y + dot_radius)],
                         fill=mean_color)
    
    return new_img

# Example usage
matrix_size = (6, 35)  # Define the granularity of the LED matrix
img_path = 'gradient.jpg'
led_img = image_to_led_style(img_path, matrix_size)

# Display or save the LED style image
led_img.show()  # This will display the image
# led_img.save('led_style_output.jpg')  # This will save the image to a file

# %%
# Out:
# {0: (np.int64(254), np.int64(59), np.int64(62)), 1: (np.int64(254), np.int64(68), np.int64(114)), 2: (np.int64(254), np.int64(77), np.int64(156)), 3: (np.int64(253), np.int64(85), np.int64(190)), 4: (np.int64(252), np.int64(96), np.int64(232)), 5: (np.int64(244), np.int64(102), np.int64(254)), 6: (np.int64(209), np.int64(105), np.int64(254)), 7: (np.int64(170), np.int64(108), np.int64(254)), 8: (np.int64(137), np.int64(111), np.int64(254)), 9: (np.int64(85), np.int64(116), np.int64(254)), 10: (np.int64(50), np.int64(122), np.int64(254)), 11: (np.int64(45), np.int64(140), np.int64(254)), 12: (np.int64(38), np.int64(160), np.int64(254)), 13: (np.int64(34), np.int64(176), np.int64(254)), 14: (np.int64(26), np.int64(191), np.int64(254)), 15: (np.int64(12), np.int64(212), np.int64(254)), 16: (np.int64(3), np.int64(226), np.int64(253)), 17: (np.int64(35), np.int64(225), np.int64(233)), 18: (np.int64(67), np.int64(219), np.int64(198)), 19: (np.int64(87), np.int64(215), np.int64(169)), 20: (np.int64(104), np.int64(211), np.int64(142)), 21: (np.int64(124), np.int64(206), np.int64(103)), 22: (np.int64(140), np.int64(203), np.int64(68)), 23: (np.int64(155), np.int64(200), np.int64(62)), 24: (np.int64(177), np.int64(198), np.int64(63)), 25: (np.int64(196), np.int64(195), np.int64(64)), 26: (np.int64(209), np.int64(193), np.int64(64)), 27: (np.int64(229), np.int64(191), np.int64(64)), 28: (np.int64(247), np.int64(188), np.int64(65)), 29: (np.int64(254), np.int64(179), np.int64(64)), 30: (np.int64(254), np.int64(152), np.int64(60)), 31: (np.int64(254), np.int64(127), np.int64(57)), 32: (np.int64(254), np.int64(105), np.int64(54)), 33: (np.int64(254), np.int64(76), np.int64(51)), 34: (np.int64(254), np.int64(54), np.int64(49)), 35: (np.int64(254), np.int64(59), np.int64(61)), 36: (np.int64(254), np.int64(68), np.int64(114)), 37: (np.int64(254), np.int64(77), np.int64(156)), 38: (np.int64(253), np.int64(85), np.int64(190)), 39: (np.int64(252), np.int64(96), np.int64(232)), 40: (np.int64(244), np.int64(102), np.int64(254)), 41: (np.int64(209), np.int64(105), np.int64(254)), 42: (np.int64(170), np.int64(108), np.int64(254)), 43: (np.int64(137), np.int64(111), np.int64(254)), 44: (np.int64(85), np.int64(115), np.int64(254)), 45: (np.int64(50), np.int64(122), np.int64(254)), 46: (np.int64(45), np.int64(140), np.int64(254)), 47: (np.int64(38), np.int64(160), np.int64(254)), 48: (np.int64(34), np.int64(176), np.int64(254)), 49: (np.int64(26), np.int64(191), np.int64(254)), 50: (np.int64(13), np.int64(212), np.int64(254)), 51: (np.int64(3), np.int64(226), np.int64(253)), 52: (np.int64(35), np.int64(225), np.int64(233)), 53: (np.int64(67), np.int64(219), np.int64(198)), 54: (np.int64(87), np.int64(215), np.int64(169)), 55: (np.int64(104), np.int64(211), np.int64(142)), 56: (np.int64(124), np.int64(206), np.int64(103)), 57: (np.int64(140), np.int64(203), np.int64(68)), 58: (np.int64(155), np.int64(200), np.int64(62)), 59: (np.int64(177), np.int64(197), np.int64(63)), 60: (np.int64(196), np.int64(195), np.int64(64)), 61: (np.int64(209), np.int64(193), np.int64(64)), 62: (np.int64(229), np.int64(191), np.int64(64)), 63: (np.int64(247), np.int64(188), np.int64(65)), 64: (np.int64(254), np.int64(179), np.int64(64)), 65: (np.int64(254), np.int64(152), np.int64(60)), 66: (np.int64(254), np.int64(127), np.int64(57)), 67: (np.int64(254), np.int64(106), np.int64(55)), 68: (np.int64(254), np.int64(76), np.int64(51)), 69: (np.int64(254), np.int64(54), np.int64(49)), 70: (np.int64(254), np.int64(59), np.int64(62)), 71: (np.int64(254), np.int64(68), np.int64(114)), 72: (np.int64(254), np.int64(77), np.int64(156)), 73: (np.int64(253), np.int64(85), np.int64(190)), 74: (np.int64(251), np.int64(96), np.int64(232)), 75: (np.int64(244), np.int64(102), np.int64(254)), 76: (np.int64(209), np.int64(105), np.int64(254)), 77: (np.int64(170), np.int64(108), np.int64(254)), 78: (np.int64(137), np.int64(111), np.int64(254)), 79: (np.int64(85), np.int64(116), np.int64(254)), 80 ...

# %%
from PIL import Image
import numpy as np
import requests
from collections import Counter


rows = 6
cols = 35

# Firebase configuration
firebase_url = "https://allprojects68-default-rtdb.asia-southeast1.firebasedatabase.app/vaiLED/"
color_data_node = "img"  # Set a name for the node where you want to store the data

def upload_color_to_firebase(led_index, rgb_tuple):
    # Store data under vaiLED/img/{led_index}
    url = f"{firebase_url}{color_data_node}/{led_index}.json"
    # Convert NumPy int64 to Python int to avoid serialization issues
    data = [
        int(rgb_tuple[0]),
        int(rgb_tuple[1]),
        int(rgb_tuple[2])
    ]
    try:
        response = requests.put(url, json=data)
        if response.status_code == 200:
            print(f"Successfully updated LED {led_index} with color {rgb_tuple}")
        else:
            print(f"Failed to update LED {led_index}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error updating LED {led_index} in Firebase: {e}")

def get_dominant_color(image):
    # Convert the image to a list of pixels
    pixels = np.array(image).reshape(-1, 3)
    # Convert each pixel to a tuple (R, G, B)
    pixels = [tuple(pixel) for pixel in pixels]
    # Use Counter to find the most common color
    most_common = Counter(pixels).most_common(1)
    return most_common[0][0]  # Return the most common color

# def divide_image_to_dict_and_upload(img_path, matrix_size):
#     # Load the image
#     img = Image.open(img_path)
#     img = img.convert('RGB')
    
#     # Determine the size of each block
#     width, height = img.size
#     block_width = width // matrix_size[1]
#     block_height = height // matrix_size[0]
    
#     # Counter for dictionary keys
#     counter = 0
    
#     # Iterate over each block
#     for i in range(matrix_size[0]):
#         for j in range(matrix_size[1]):
#             # Compute the bounds of the block
#             left = j * block_width
#             right = (j + 1) * block_width
#             top = i * block_height
#             bottom = (i + 1) * block_height
            
#             # Crop the block and calculate the dominant color
#             block = img.crop((left, top, right, bottom))
#             dominant_color = get_dominant_color(block)
            
#             # Upload the dominant color to Firebase
#             upload_color_to_firebase(counter, dominant_color)
#             counter += 1

def divide_image_to_dict_and_upload(img_path, matrix_size):
    # Load the image
    img = Image.open(img_path)
    img = img.convert('RGB')
    
    # Determine the size of each block
    width, height = img.size
    block_width = width // matrix_size[1]
    block_height = height // matrix_size[0]
    
    # Iterate over each block
    for i in range(matrix_size[0]):
        for j in range(matrix_size[1]):
            # Compute the bounds of the block
            left = j * block_width
            right = (j + 1) * block_width
            top = i * block_height
            bottom = (i + 1) * block_height
            
            # Crop the block and calculate the dominant color
            block = img.crop((left, top, right, bottom))
            dominant_color = get_dominant_color(block)
            
            # Calculate the counter in zigzag pattern
            if i % 2 == 0:
                # Even rows: left to right
                counter = i * matrix_size[1] + j
            else:
                # Odd rows: right to left
                counter = (i + 1) * matrix_size[1] - 1 - j
            
            # Upload the dominant color to Firebase
            upload_color_to_firebase(counter, dominant_color)

# Example usage
matrix_size = (rows, cols)  # Divide the image into a 3x3 matrix
img_path = 'gradient.jpg'  # Path to your image file
divide_image_to_dict_and_upload(img_path, matrix_size)
# Out:
# Successfully updated LED 0 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 1 with color (np.uint8(255), np.uint8(66), np.uint8(98))
# Successfully updated LED 2 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 3 with color (np.uint8(254), np.uint8(88), np.uint8(198))
# Successfully updated LED 4 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 5 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 6 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 7 with color (np.uint8(161), np.uint8(109), np.uint8(254))
# Successfully updated LED 8 with color (np.uint8(139), np.uint8(112), np.uint8(255))
# Successfully updated LED 9 with color (np.uint8(62), np.uint8(118), np.uint8(255))
# Successfully updated LED 10 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 11 with color (np.uint8(45), np.uint8(142), np.uint8(255))
# Successfully updated LED 12 with color (np.uint8(37), np.uint8(167), np.uint8(255))
# Successfully updated LED 13 with color (np.uint8(32), np.uint8(178), np.uint8(255))
# Successfully updated LED 14 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 15 with color (np.uint8(10), np.uint8(213), np.uint8(254))
# Successfully updated LED 16 with color (np.uint8(0), np.uint8(228), np.uint8(255))
# Successfully updated LED 17 with color (np.uint8(31), np.uint8(227), np.uint8(239))
# Successfully updated LED 18 with color (np.uint8(72), np.uint8(219), np.uint8(193))
# Successfully updated LED 19 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 20 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 21 with color (np.uint8(119), np.uint8(208), np.uint8(118))
# Successfully updated LED 22 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 23 with color (np.uint8(163), np.uint8(199), np.uint8(63))
# Successfully updated LED 24 with color (np.uint8(180), np.uint8(198), np.uint8(64))
# Successfully updated LED 25 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 26 with color (np.uint8(204), np.uint8(195), np.uint8(64))
# Successfully updated LED 27 with color (np.uint8(236), np.uint8(191), np.uint8(64))
# Successfully updated LED 28 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 29 with color (np.uint8(255), np.uint8(185), np.uint8(64))
# Successfully updated LED 30 with color (np.uint8(255), np.uint8(156), np.uint8(63))
# Successfully updated LED 31 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 32 with color (np.uint8(255), np.uint8(114), np.uint8(58))
# Successfully updated LED 33 with color (np.uint8(255), np.uint8(84), np.uint8(54))
# Successfully updated LED 34 with color (np.uint8(255), np.uint8(52), np.uint8(48))
# Successfully updated LED 69 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 68 with color (np.uint8(255), np.uint8(66), np.uint8(98))
# Successfully updated LED 67 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 66 with color (np.uint8(254), np.uint8(84), np.uint8(183))
# Successfully updated LED 65 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 64 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 63 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 62 with color (np.uint8(161), np.uint8(109), np.uint8(254))
# Successfully updated LED 61 with color (np.uint8(139), np.uint8(112), np.uint8(255))
# Successfully updated LED 60 with color (np.uint8(62), np.uint8(118), np.uint8(255))
# Successfully updated LED 59 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 58 with color (np.uint8(45), np.uint8(142), np.uint8(255))
# Successfully updated LED 57 with color (np.uint8(39), np.uint8(162), np.uint8(255))
# Successfully updated LED 56 with color (np.uint8(32), np.uint8(178), np.uint8(255))
# Successfully updated LED 55 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 54 with color (np.uint8(19), np.uint8(207), np.uint8(255))
# Successfully updated LED 53 with color (np.uint8(0), np.uint8(228), np.uint8(255))
# Successfully updated LED 52 with color (np.uint8(46), np.uint8(224), np.uint8(224))
# Successfully updated LED 51 with color (np.uint8(74), np.uint8(218), np.uint8(191))
# Successfully updated LED 50 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 49 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 48 with color (np.uint8(129), np.uint8(206), np.uint8(94))
# Successfully updated LED 47 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 46 with color (np.uint8(163), np.uint8(199), np.uint8(63))
# Successfully updated LED 45 with color (np.uint8(171), np.uint8(199), np.uint8(63))
# Successfully updated LED 44 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 43 with color (np.uint8(211), np.uint8(193), np.uint8(65))
# Successfully updated LED 42 with color (np.uint8(232), np.uint8(191), np.uint8(65))
# Successfully updated LED 41 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 40 with color (np.uint8(254), np.uint8(188), np.uint8(65))
# Successfully updated LED 39 with color (np.uint8(255), np.uint8(156), np.uint8(63))
# Successfully updated LED 38 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 37 with color (np.uint8(255), np.uint8(114), np.uint8(58))
# Successfully updated LED 36 with color (np.uint8(255), np.uint8(84), np.uint8(54))
# Successfully updated LED 35 with color (np.uint8(255), np.uint8(52), np.uint8(48))
# Successfully updated LED 70 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 71 with color (np.uint8(255), np.uint8(66), np.uint8(98))
# Successfully updated LED 72 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 73 with color (np.uint8(254), np.uint8(88), np.uint8(198))
# Successfully updated LED 74 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 75 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 76 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 77 with color (np.uint8(161), np.uint8(109), np.uint8(254))
# Successfully updated LED 78 with color (np.uint8(118), np.uint8(113), np.uint8(255))
# Successfully updated LED 79 with color (np.uint8(74), np.uint8(117), np.uint8(255))
# Successfully updated LED 80 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 81 with color (np.uint8(48), np.uint8(130), np.uint8(255))
# Successfully updated LED 82 with color (np.uint8(39), np.uint8(162), np.uint8(255))
# Successfully updated LED 83 with color (np.uint8(32), np.uint8(178), np.uint8(255))
# Successfully updated LED 84 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 85 with color (np.uint8(10), np.uint8(220), np.uint8(255))
# Successfully updated LED 86 with color (np.uint8(0), np.uint8(228), np.uint8(255))
# Successfully updated LED 87 with color (np.uint8(43), np.uint8(225), np.uint8(226))
# Successfully updated LED 88 with color (np.uint8(65), np.uint8(220), np.uint8(204))
# Successfully updated LED 89 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 90 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 91 with color (np.uint8(119), np.uint8(208), np.uint8(118))
# Successfully updated LED 92 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 93 with color (np.uint8(150), np.uint8(201), np.uint8(62))
# Successfully updated LED 94 with color (np.uint8(180), np.uint8(198), np.uint8(64))
# Successfully updated LED 95 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 96 with color (np.uint8(204), np.uint8(195), np.uint8(64))
# Successfully updated LED 97 with color (np.uint8(232), np.uint8(191), np.uint8(65))
# Successfully updated LED 98 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 99 with color (np.uint8(254), np.uint8(188), np.uint8(65))
# Successfully updated LED 100 with color (np.uint8(255), np.uint8(163), np.uint8(62))
# Successfully updated LED 101 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 102 with color (np.uint8(255), np.uint8(116), np.uint8(57))
# Successfully updated LED 103 with color (np.uint8(255), np.uint8(89), np.uint8(53))
# Successfully updated LED 104 with color (np.uint8(255), np.uint8(52), np.uint8(48))
# Successfully updated LED 139 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 138 with color (np.uint8(255), np.uint8(71), np.uint8(131))
# Successfully updated LED 137 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 136 with color (np.uint8(254), np.uint8(88), np.uint8(198))
# Successfully updated LED 135 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 134 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 133 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 132 with color (np.uint8(161), np.uint8(109), np.uint8(254))
# Successfully updated LED 131 with color (np.uint8(139), np.uint8(112), np.uint8(255))
# Successfully updated LED 130 with color (np.uint8(74), np.uint8(117), np.uint8(255))
# Successfully updated LED 129 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 128 with color (np.uint8(44), np.uint8(144), np.uint8(255))
# Successfully updated LED 127 with color (np.uint8(37), np.uint8(167), np.uint8(255))
# Successfully updated LED 126 with color (np.uint8(32), np.uint8(178), np.uint8(255))
# Successfully updated LED 125 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 124 with color (np.uint8(21), np.uint8(207), np.uint8(254))
# Successfully updated LED 123 with color (np.uint8(0), np.uint8(228), np.uint8(255))
# Successfully updated LED 122 with color (np.uint8(45), np.uint8(224), np.uint8(228))
# Successfully updated LED 121 with color (np.uint8(65), np.uint8(220), np.uint8(204))
# Successfully updated LED 120 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 119 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 118 with color (np.uint8(129), np.uint8(206), np.uint8(94))
# Successfully updated LED 117 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 116 with color (np.uint8(163), np.uint8(199), np.uint8(63))
# Successfully updated LED 115 with color (np.uint8(180), np.uint8(198), np.uint8(64))
# Successfully updated LED 114 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 113 with color (np.uint8(204), np.uint8(195), np.uint8(64))
# Successfully updated LED 112 with color (np.uint8(230), np.uint8(191), np.uint8(64))
# Successfully updated LED 111 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 110 with color (np.uint8(255), np.uint8(185), np.uint8(64))
# Successfully updated LED 109 with color (np.uint8(255), np.uint8(140), np.uint8(59))
# Successfully updated LED 108 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 107 with color (np.uint8(255), np.uint8(114), np.uint8(58))
# Successfully updated LED 106 with color (np.uint8(255), np.uint8(63), np.uint8(50))
# Successfully updated LED 105 with color (np.uint8(255), np.uint8(52), np.uint8(48))
# Successfully updated LED 140 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 141 with color (np.uint8(255), np.uint8(66), np.uint8(98))
# Successfully updated LED 142 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 143 with color (np.uint8(254), np.uint8(81), np.uint8(171))
# Successfully updated LED 144 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 145 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 146 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 147 with color (np.uint8(165), np.uint8(110), np.uint8(255))
# Successfully updated LED 148 with color (np.uint8(118), np.uint8(113), np.uint8(255))
# Successfully updated LED 149 with color (np.uint8(62), np.uint8(118), np.uint8(255))
# Successfully updated LED 150 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 151 with color (np.uint8(46), np.uint8(144), np.uint8(255))
# Successfully updated LED 152 with color (np.uint8(39), np.uint8(162), np.uint8(255))
# Successfully updated LED 153 with color (np.uint8(32), np.uint8(178), np.uint8(255))
# Successfully updated LED 154 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 155 with color (np.uint8(10), np.uint8(220), np.uint8(255))
# Successfully updated LED 156 with color (np.uint8(0), np.uint8(228), np.uint8(255))
# Successfully updated LED 157 with color (np.uint8(41), np.uint8(224), np.uint8(232))
# Successfully updated LED 158 with color (np.uint8(65), np.uint8(220), np.uint8(204))
# Successfully updated LED 159 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 160 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 161 with color (np.uint8(120), np.uint8(207), np.uint8(113))
# Successfully updated LED 162 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 163 with color (np.uint8(163), np.uint8(199), np.uint8(63))
# Successfully updated LED 164 with color (np.uint8(171), np.uint8(199), np.uint8(63))
# Successfully updated LED 165 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 166 with color (np.uint8(204), np.uint8(195), np.uint8(64))
# Successfully updated LED 167 with color (np.uint8(230), np.uint8(191), np.uint8(64))
# Successfully updated LED 168 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 169 with color (np.uint8(254), np.uint8(188), np.uint8(65))
# Successfully updated LED 170 with color (np.uint8(255), np.uint8(150), np.uint8(59))
# Successfully updated LED 171 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 172 with color (np.uint8(255), np.uint8(114), np.uint8(58))
# Successfully updated LED 173 with color (np.uint8(255), np.uint8(63), np.uint8(50))
# Successfully updated LED 174 with color (np.uint8(255), np.uint8(52), np.uint8(48))
# Successfully updated LED 209 with color (np.uint8(255), np.uint8(57), np.uint8(46))
# Successfully updated LED 208 with color (np.uint8(254), np.uint8(68), np.uint8(107))
# Successfully updated LED 207 with color (np.uint8(255), np.uint8(79), np.uint8(164))
# Successfully updated LED 206 with color (np.uint8(254), np.uint8(81), np.uint8(171))
# Successfully updated LED 205 with color (np.uint8(252), np.uint8(100), np.uint8(245))
# Successfully updated LED 204 with color (np.uint8(251), np.uint8(102), np.uint8(254))
# Successfully updated LED 203 with color (np.uint8(199), np.uint8(106), np.uint8(255))
# Successfully updated LED 202 with color (np.uint8(161), np.uint8(109), np.uint8(254))
# Successfully updated LED 201 with color (np.uint8(118), np.uint8(113), np.uint8(255))
# Successfully updated LED 200 with color (np.uint8(62), np.uint8(118), np.uint8(255))
# Successfully updated LED 199 with color (np.uint8(51), np.uint8(121), np.uint8(255))
# Successfully updated LED 198 with color (np.uint8(46), np.uint8(144), np.uint8(255))
# Successfully updated LED 197 with color (np.uint8(37), np.uint8(167), np.uint8(255))
# Successfully updated LED 196 with color (np.uint8(35), np.uint8(176), np.uint8(255))
# Successfully updated LED 195 with color (np.uint8(26), np.uint8(196), np.uint8(255))
# Successfully updated LED 194 with color (np.uint8(19), np.uint8(207), np.uint8(253))
# Successfully updated LED 193 with color (np.uint8(0), np.uint8(230), np.uint8(254))
# Successfully updated LED 192 with color (np.uint8(40), np.uint8(225), np.uint8(230))
# Successfully updated LED 191 with color (np.uint8(65), np.uint8(220), np.uint8(204))
# Successfully updated LED 190 with color (np.uint8(89), np.uint8(215), np.uint8(168))
# Successfully updated LED 189 with color (np.uint8(99), np.uint8(213), np.uint8(153))
# Successfully updated LED 188 with color (np.uint8(125), np.uint8(207), np.uint8(109))
# Successfully updated LED 187 with color (np.uint8(143), np.uint8(202), np.uint8(62))
# Successfully updated LED 186 with color (np.uint8(163), np.uint8(199), np.uint8(63))
# Successfully updated LED 185 with color (np.uint8(180), np.uint8(198), np.uint8(64))
# Successfully updated LED 184 with color (np.uint8(196), np.uint8(196), np.uint8(64))
# Successfully updated LED 183 with color (np.uint8(204), np.uint8(195), np.uint8(64))
# Successfully updated LED 182 with color (np.uint8(230), np.uint8(191), np.uint8(64))
# Successfully updated LED 181 with color (np.uint8(253), np.uint8(189), np.uint8(65))
# Successfully updated LED 180 with color (np.uint8(254), np.uint8(188), np.uint8(65))
# Successfully updated LED 179 with color (np.uint8(255), np.uint8(158), np.uint8(61))
# Successfully updated LED 178 with color (np.uint8(255), np.uint8(123), np.uint8(58))
# Successfully updated LED 177 with color (np.uint8(255), np.uint8(114), np.uint8(58))
# Successfully updated LED 176 with color (np.uint8(255), np.uint8(68), np.uint8(51))
# Successfully updated LED 175 with color (np.uint8(255), np.uint8(52), np.uint8(48))

# %%
# !pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Downloading idna-3.8-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.8 requests-2.32.3 urllib3-2.2.2
